# %% [markdown]
# Here is some text

# %%
import os
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# Load the data

# %%
X = pd.DataFrame(pd.read_csv(os.getcwd()+'/Code/Projects/RFM/GoogleWGSN.csv'))

# %%
print X
# Out:
#      fullVisitorId     visitId  visitstarttime      Date  TotalsBounces  \
# 0     1.000000e+17  1499036357      1499036357  20170702              1
# 1     1.010000e+17  1498917386      1498917386  20170701              1
# 2     1.000000e+18  1498973872      1498973872  20170702              0
# 3     1.000000e+18  1498973872      1498973872  20170702              0
# 4     1.000000e+18  1498973872      1498973872  20170702              0
# 5     1.000000e+18  1498973872      1498973872  20170702              0
# 6     1.000000e+18  1498973872      1498973872  20170702              0
# 7     1.000000e+18  1498973872      1498973872  20170702              0
# 8     1.000000e+18  1498973872      1498973872  20170702              0
# 9     1.000000e+18  1498973872      1498973872  20170702              0
# 10    1.000000e+18  1498973872      1498973872  20170702              0
# 11    1.000000e+18  1498973872      1498973872  20170702              0
# ...
